# %%
#q1
import pandas as pd
import numpy as np
import matplotlib.pyplot  as plt
# %matplotlib inline
import random as rd

# %%
#q2
import os
current_path = os.getcwd()
print(current_path)
# Out:
# C:\Users\KIIT\ml-krs

# %%
#q3
df=pd.read_csv('transfusion.csv')
df
# Out:
#      Recency (months)  Frequency (times)  Monetary (c.c. blood)  \
# 0                   2                 50                  12500
# 1                   0                 13                   3250
# 2                   1                 16                   4000
# 3                   2                 20                   5000
# 4                   1                 24                   6000
# ..                ...                ...                    ...
# 743                23                  2                    500
# 744                21                  2                    500
# 745                23                  3                    750
# 746                39                  1                    250
# 747                72                  1                    250
#
#      Time (months)  whether he/she donated blood in March 2007
# 0               98                                           1
# 1               28                                           1
# ...

# %%
#q4
df.columns.values
# Out:
# array(['Recency (months)', 'Frequency (times)', 'Monetary (c.c. blood)',
#        'Time (months)', 'whether he/she donated blood in March 2007'],
#       dtype=object)

# %%
#q5
df.info
# Out:
# <bound method DataFrame.info of      Recency (months)  Frequency (times)  Monetary (c.c. blood)  \
# 0                   2                 50                  12500
# 1                   0                 13                   3250
# 2                   1                 16                   4000
# 3                   2                 20                   5000
# 4                   1                 24                   6000
# ..                ...                ...                    ...
# 743                23                  2                    500
# 744                21                  2                    500
# 745                23                  3                    750
# 746                39                  1                    250
# 747                72                  1                    250
#
#      Time (months)  whether he/she donated blood in March 2007
# 0               98                                           1
# ...

# %%
#q6
print(df.isnull().sum())
# Out:
# Recency (months)                              0
# Frequency (times)                             0
# Monetary (c.c. blood)                         0
# Time (months)                                 0
# whether he/she donated blood in March 2007    0
# dtype: int64
# None

# %%
#q6
df.dropna(inplace=True)
df
# Out:
#      Recency (months)  Frequency (times)  Monetary (c.c. blood)  \
# 0                   2                 50                  12500
# 1                   0                 13                   3250
# 2                   1                 16                   4000
# 3                   2                 20                   5000
# 4                   1                 24                   6000
# ..                ...                ...                    ...
# 743                23                  2                    500
# 744                21                  2                    500
# 745                23                  3                    750
# 746                39                  1                    250
# 747                72                  1                    250
#
#      Time (months)  whether he/she donated blood in March 2007
# 0               98                                           1
# 1               28                                           1
# ...

# %%
#q7
df.describe()
# Out:
#        Recency (months)  Frequency (times)  Monetary (c.c. blood)  \
# count        748.000000         748.000000             748.000000
# mean           9.506684           5.514706            1378.676471
# std            8.095396           5.839307            1459.826781
# min            0.000000           1.000000             250.000000
# 25%            2.750000           2.000000             500.000000
# 50%            7.000000           4.000000            1000.000000
# 75%           14.000000           7.000000            1750.000000
# max           74.000000          50.000000           12500.000000
#
#        Time (months)  whether he/she donated blood in March 2007
# count     748.000000                                  748.000000
# mean       34.282086                                    0.237968
# std        24.376714                                    0.426124
# min         2.000000                                    0.000000
# ...

# %%
#q8
df.max(axis=0)
# Out:
# Recency (months)                                 74
# Frequency (times)                                50
# Monetary (c.c. blood)                         12500
# Time (months)                                    98
# whether he/she donated blood in March 2007        1
# dtype: int64

# %%
#q8
df.min(axis=0)
# Out:
# Recency (months)                                0
# Frequency (times)                               1
# Monetary (c.c. blood)                         250
# Time (months)                                   2
# whether he/she donated blood in March 2007      0
# dtype: int64

# %%
#q9
sum=df['whether he/she donated blood in March 2007'].sum()
print("The number of people who donated blood:    ",sum)
print("The number of people who have not donated blood:   ",df.shape[0]-sum)
# Out:
# The number of people who donated blood:     178
# The number of people who have not donated blood:    570

# %%
#q10
print("Number of rows: ",df.shape[0])
print("Number of columns: ",df.shape[1])
# Out:
# Number of rows:  748
# Number of columns:  5

# %%
#q11
df.nunique()
# Out:
# Recency (months)                              31
# Frequency (times)                             33
# Monetary (c.c. blood)                         33
# Time (months)                                 78
# whether he/she donated blood in March 2007     2
# dtype: int64

# %%
#q12
df['blood_donation']=df['whether he/she donated blood in March 2007']
df.drop('whether he/she donated blood in March 2007',axis=1,inplace=True)
df
# Out:
#      Recency (months)  Frequency (times)  Monetary (c.c. blood)  \
# 0                   2                 50                  12500
# 1                   0                 13                   3250
# 2                   1                 16                   4000
# 3                   2                 20                   5000
# 4                   1                 24                   6000
# ..                ...                ...                    ...
# 743                23                  2                    500
# 744                21                  2                    500
# 745                23                  3                    750
# 746                39                  1                    250
# 747                72                  1                    250
#
#      Time (months)  blood_donation
# 0               98               1
# 1               28               1
# 2               35               1
# 3               45               1
# ...

# %%
#q13
Df=df.to_numpy()
plt.hist(Df)
# Out:
# (array([[748.,   0.,   0.,   0.,   0.,   0.,   0.,   0.,   0.,   0.],
#         [748.,   0.,   0.,   0.,   0.,   0.,   0.,   0.,   0.,   0.],
#         [419., 212.,  72.,  26.,  10.,   1.,   2.,   1.,   3.,   2.],
#         [748.,   0.,   0.,   0.,   0.,   0.,   0.,   0.,   0.,   0.],
#         [748.,   0.,   0.,   0.,   0.,   0.,   0.,   0.,   0.,   0.]]),
#  array([    0.,  1250.,  2500.,  3750.,  5000.,  6250.,  7500.,  8750.,
#         10000., 11250., 12500.]),
#  <a list of 5 BarContainer objects>)

# %%
#q14

plt.bar(np.arange(0,748),df['blood_donation']>0,color='r',alpha=1,label='Donated')
plt.legend()

# %%
#q15
plt.figure(figsize=(10,10))
ax = plt.axes(projection ="3d")
ax.scatter3D(df['Recency (months)'], df['Frequency (times)'], df['blood_donation'], color = "#40E0D0")
plt.title("KRS")
ax.set_xlabel('Recency (months)')
ax.set_ylabel('Frequency (times)')
ax.set_zlabel('blood_donation')
plt.legend()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
#q16
plt.figure(figsize=(20,20))
plt.pie(df.mean(axis=0).to_numpy(),labels=['Recency (months)',	'Frequency (times)'	,'Monetary (c.c. blood)'	,'Time (months)'	,'blood_donation'],colors=['#40E0D0','g','b','y','r'])
plt.legend()

# %%
#q17
plt.figure(figsize=(10,10))
Df=df.drop(['blood_donation'],axis=1).to_numpy()
plt.boxplot(Df,labels=['Recency (months)','Frequency (times)','Monetary (c.c. blood)','Time (months)'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1a6c07ca550>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1a6c07caaf0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1a6c07ca280>,
# ...
#  'medians': [<matplotlib.lines.Line2D at 0x1a6c07d50d0>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x1a6c07d53a0>,
# ...
#  'means': []}

# %%
#q18
plt.figure(figsize=(10,10))

plt.bar(df['Time (months)'], df['blood_donation'], color ='#000080',width =1)
plt.xlabel('Time (months)')
plt.ylabel('blood_donation')
plt.title('Time Vs Blood Donation')
# Out:
# Text(0.5, 1.0, 'Time Vs Blood Donation')
