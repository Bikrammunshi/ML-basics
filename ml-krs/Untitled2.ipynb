# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn import metrics

# %%
fish=pd.read_csv('Fish.csv')
fish
# Out:
#     Species  Weight  Length1  Length2  Length3   Height   Width
# 0     Bream   242.0     23.2     25.4     30.0  11.5200  4.0200
# 1     Bream   290.0     24.0     26.3     31.2  12.4800  4.3056
# 2     Bream   340.0     23.9     26.5     31.1  12.3778  4.6961
# 3     Bream   363.0     26.3     29.0     33.5  12.7300  4.4555
# 4     Bream   430.0     26.5     29.0     34.0  12.4440  5.1340
# ..      ...     ...      ...      ...      ...      ...     ...
# 154   Smelt    12.2     11.5     12.2     13.4   2.0904  1.3936
# 155   Smelt    13.4     11.7     12.4     13.5   2.4300  1.2690
# 156   Smelt    12.2     12.1     13.0     13.8   2.2770  1.2558
# 157   Smelt    19.7     13.2     14.3     15.2   2.8728  2.0672
# 158   Smelt    19.9     13.8     15.0     16.2   2.9322  1.8792
#
# [159 rows x 7 columns]

# %%
fish.isnull().sum()
# Out:
# Species    0
# Weight     0
# Length1    0
# Length2    0
# Length3    0
# Height     0
# Width      0
# dtype: int64

# %%
fish.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 159 entries, 0 to 158
# Data columns (total 7 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Species  159 non-null    object
#  1   Weight   159 non-null    float64
#  2   Length1  159 non-null    float64
#  3   Length2  159 non-null    float64
#  4   Length3  159 non-null    float64
#  5   Height   159 non-null    float64
#  6   Width    159 non-null    float64
# dtypes: float64(6), object(1)
# memory usage: 8.8+ KB

# %%
fish.describe()
# Out:
#             Weight     Length1     Length2     Length3      Height       Width
# count   159.000000  159.000000  159.000000  159.000000  159.000000  159.000000
# mean    398.326415   26.247170   28.415723   31.227044    8.970994    4.417486
# std     357.978317    9.996441   10.716328   11.610246    4.286208    1.685804
# min       0.000000    7.500000    8.400000    8.800000    1.728400    1.047600
# 25%     120.000000   19.050000   21.000000   23.150000    5.944800    3.385650
# 50%     273.000000   25.200000   27.300000   29.400000    7.786000    4.248500
# 75%     650.000000   32.700000   35.500000   39.650000   12.365900    5.584500
# max    1650.000000   59.000000   63.400000   68.000000   18.957000    8.142000

# %%
given=fish.iloc[:,2:7]
output=fish.iloc[:,1]

# %%
given
# Out:
#      Length1  Length2  Length3   Height   Width
# 0       23.2     25.4     30.0  11.5200  4.0200
# 1       24.0     26.3     31.2  12.4800  4.3056
# 2       23.9     26.5     31.1  12.3778  4.6961
# 3       26.3     29.0     33.5  12.7300  4.4555
# 4       26.5     29.0     34.0  12.4440  5.1340
# ..       ...      ...      ...      ...     ...
# 154     11.5     12.2     13.4   2.0904  1.3936
# 155     11.7     12.4     13.5   2.4300  1.2690
# 156     12.1     13.0     13.8   2.2770  1.2558
# 157     13.2     14.3     15.2   2.8728  2.0672
# 158     13.8     15.0     16.2   2.9322  1.8792
#
# [159 rows x 5 columns]

# %%
output
# Out:
# 0      242.0
# 1      290.0
# 2      340.0
# 3      363.0
# 4      430.0
#        ...
# 154     12.2
# 155     13.4
# 156     12.2
# 157     19.7
# 158     19.9
# Name: Weight, Length: 159, dtype: float64

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(given,output,test_size=0.2,random_state=0)

# %%
model=LinearRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
predict_train=model.predict(x_train)
predict_test=model.predict(x_test)
predict_train
# Out:
# array([1059.59461179,  418.72452009,  606.53505825,  268.80139783,
#         436.59422731,  636.15235102,  722.21399175,  168.48594122,
#         616.94397623,  -18.36455129,  241.68357973,  685.75041361,
#         -64.03822107,  292.6449752 ,  290.79999206,  377.43736104,
#         646.5536728 ,  434.8117459 ,  788.76113485,  -70.72398385,
#        -115.92397689,  372.35827463,   98.67693338,  166.04758125,
#         414.93025681,  536.20162009, -150.85305491,  566.67508671,
#        -134.28134714, -167.70908027,  208.87049623,  190.98714304,
#         174.70836483, -192.22793855, 1024.4877142 ,  895.701389  ,
#         757.60573587,  260.86732612,  273.23022179,  212.87282241,
#         175.12543995,  838.2532259 ,  392.23344589,  315.85463841,
#         230.94345336,  225.67577195,  554.00322367,  759.00802687,
#         638.63281023,  710.75668328,  632.59586215,  610.43153184,
#          88.02104143,  334.69786251,   35.00403775,  435.38809904,
# ...

# %%
from sklearn import metrics

# %%
score=metrics.r2_score(y_test,predict_test)
scores=[]
for i in range(5000):
    x_train,x_test,y_train,y_test=train_test_split(given,output,test_size=0.2,random_state=i)
    model.fit(x_train,y_train)
    predict_test=model.predict(x_test)
    score=metrics.r2_score(y_test,predict_test)
    scores.append(score)
print(max(scores))
print(scores.index(max(scores)))
# Out:
# 0.95601950488825
# 1120
